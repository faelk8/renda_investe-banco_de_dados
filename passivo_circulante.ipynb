# %%
import pandas as pd 
import json

from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
arquivo = "/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/balanco/BHIA.json"
with open(arquivo, "r", encoding="utf-8") as f:
    dados = json.load(f)

# %%
empresa = dados['data']

# %%
def ativo_id():
    """
    Retorna o próximo ID para a tabela ativo_circulante.ativo_total.
    O ID é gerado com base no maior valor já existente na tabela.
    Se a tabela estiver vazia, o ID começará em 1.
    """
    df = pd.read_csv('data/dataframe/passivo_circulante/passivo_total.csv')
    if df.empty:
        return 1
    else:
        return df['codigo'].max() + 1

def inserir_ativo(base, lista_prefixos, lista_sufixos, lista_valores, ID):
    # con = PostgresConnector()
    for nome, descricao, valor in zip(lista_prefixos, lista_sufixos, lista_valores):
        try:
            if base == "Obrigações Sociais e Trabalhistas":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_obr_sociais_trabalhistas = pd.read_csv('data/dataframe/passivo_circulante/obr_sociais_trabalhistas.csv')
                df_obr_sociais_trabalhistas = pd.concat([df_obr_sociais_trabalhistas, temp], ignore_index=True)
                df_obr_sociais_trabalhistas.to_csv('data/dataframe/passivo_circulante/obr_sociais_trabalhistas.csv',index=False)
                # tabela = "passivo_circulante.obr_sociais_trabalhistas"
                # key = "obr_sociais_trabalhistas_id"

            elif base == "Fornecedores":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_fornecedor = pd.read_csv('data/dataframe/passivo_circulante/fornecedor.csv')
                df_fornecedor = pd.concat([df_fornecedor, temp], ignore_index=True)
                df_fornecedor.to_csv('data/dataframe/passivo_circulante/fornecedor.csv',index=False)
                # tabela = "passivo_circulante.fornecedor"
                # key = "fornecedor_id"
            
            elif base == "Obrigações Fiscais":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_obr_fiscais = pd.read_csv('data/dataframe/passivo_circulante/obr_fiscais.csv')
                df_obr_fiscais = pd.concat([df_obr_fiscais, temp], ignore_index=True)
                df_obr_fiscais.to_csv('data/dataframe/passivo_circulante/obr_fiscais.csv',index=False)
                # tabela = "passivo_circulante.obr_fiscais"
                # key = "obr_fiscais_id"
            
            elif base == "Empréstimos e Financiamentos":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_emprestimo_financiamento = pd.read_csv('data/dataframe/passivo_circulante/emprestimo_financiamento.csv')
                df_emprestimo_financiamento = pd.concat([df_emprestimo_financiamento, temp], ignore_index=True)
                df_emprestimo_financiamento.to_csv('data/dataframe/passivo_circulante/emprestimo_financiamento.csv',index=False)
                # tabela = "passivo_circulante.emprestimo_financiamento"
                # key = "emprestimo_financiamento_id"
            
            elif base == "Outras Obrigações":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_outras_obrigacoes = pd.read_csv('data/dataframe/passivo_circulante/outras_obrigacoes.csv')
                df_outras_obrigacoes = pd.concat([df_outras_obrigacoes, temp], ignore_index=True)
                df_outras_obrigacoes.to_csv('data/dataframe/passivo_circulante/outras_obrigacoes.csv',index=False)
                # tabela = "passivo_circulante.outras_obrigacoes"
                # key = "outras_obrigacoes_id"
            
            elif base == "Provisões":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_provisoes = pd.read_csv('data/dataframe/passivo_circulante/provisoes.csv')
                df_provisoes = pd.concat([df_provisoes, temp], ignore_index=True)
                df_provisoes.to_csv('data/dataframe/passivo_circulante/provisoes.csv',index=False)
                # tabela = "passivo_circulante.provisoes"
                # key = "provisoes_id"
            
            elif base == "Passivos sobre Ativos Não-Correntes a Venda e Descontinuados":
                temp = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
                temp['codigo'] = [ID]
                temp['nome'] = [nome]
                temp['descricao'] = [descricao]
                temp['valor'] = [valor]
                df_passivos = pd.read_csv('data/dataframe/passivo_circulante/passivos.csv')
                df_passivos = pd.concat([df_passivos, temp], ignore_index=True)
                df_passivos.to_csv('data/dataframe/passivo_circulante/passivos.csv',index=False)                # tabela = "passivo_circulante.passivos"
                # key = "passivos_id"

        except Exception as e:
            logger.error("Erro na função inserir_ativo")
            logger.error(f"Erro ao processar item ({nome}, {descricao}, {valor}): {e}")
            break
    # con.close()

def separar_classes(procurar, resultado, ID):
    lista_prefixos = []
    lista_sufixos = []
    lista_valores = []

    caminhos_pos_procurar = []

    # Coletar todos os caminhos abaixo do "procurar"
    for chave in resultado:
        partes = chave.split(" | ")
        indices_procurar = [i for i, p in enumerate(partes) if p == procurar]
        idx = next((i for i in indices_procurar if i + 1 <= len(partes)), None)
        if idx is not None:
            caminho = partes[idx + 1:]
            caminhos_pos_procurar.append(caminho)

    # Determinar quais caminhos são folhas
    folhas = []
    for caminho in caminhos_pos_procurar:
        is_folha = not any(
            outro != caminho and outro[:len(caminho)] == caminho
            for outro in caminhos_pos_procurar
        )
        if is_folha:
            folhas.append(caminho)

    # Agora, coletar os valores somente dos nós folha
    for chave, valor in resultado.items():
        partes = chave.split(" | ")
        indices_procurar = [i for i, p in enumerate(partes) if p == procurar]
        idx = next((i for i in indices_procurar if i + 1 <= len(partes)), None)
        if idx is None:
            continue

        caminho = partes[idx + 1:]

        if caminho in folhas:
            if len(caminho) == 0:
                lista_prefixos.append(procurar)
                lista_sufixos.append(procurar)
            elif len(caminho) == 1:
                lista_prefixos.append(caminho[0])
                lista_sufixos.append(caminho[0])
            elif len(caminho) > 1:
                lista_prefixos.append(caminho[0])
                lista_sufixos.append(caminho[1])
            lista_valores.append(valor)

    inserir_ativo(procurar, lista_prefixos, lista_sufixos, lista_valores, ID)

def circulante( id=None, COMPANIA_ID=None, dados=None):

    valor_procurado = "Passivo Total | Passivo Circulante"
    lista = ["Passivo Total | Passivo Circulante | Obrigações Sociais e Trabalhistas",
                 "Passivo Total | Passivo Circulante | Fornecedores",
                 "Passivo Total | Passivo Circulante | Obrigações Fiscais",
                 "Passivo Total | Passivo Circulante | Empréstimos e Financiamentos",
                 "Passivo Total | Passivo Circulante | Outras Obrigações",
                 "Passivo Total | Passivo Circulante | Provisões",
                 "Passivo Total | Passivo Circulante | Passivos sobre Ativos Não-Correntes a Venda e Descontinuados"
                 ]

    resultado_atual = {}

    for chave, valor in dados.items():
        if valor_procurado in chave:
            resultado_atual[chave] = valor

    for l in lista:
        valor_procurado = l
        partes = valor_procurado.split(" | ")
        if len(partes) >= 3:
            procurar = partes[2]

        resultado = {}

        for chave, valor in resultado_atual.items():
            if l in chave:
                resultado[chave] = valor
        separar_classes(procurar, resultado, id)

# %%
df_obr_sociais_trabalhistas = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_fornecedor = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_obr_fiscais = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_emprestimo_financiamento = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_outras_obrigacoes = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_provisoes = pd.DataFrame(columns=['codigo','nome','descricao','valor'])
df_passivos = pd.DataFrame(columns=['codigo','nome','descricao','valor'])

df_obr_sociais_trabalhistas.to_csv('data/dataframe/passivo_circulante/obr_sociais_trabalhistas.csv',index=False)
df_fornecedor.to_csv('data/dataframe/passivo_circulante/fornecedor.csv',index=False)
df_obr_fiscais.to_csv('data/dataframe/passivo_circulante/obr_fiscais.csv',index=False)
df_emprestimo_financiamento.to_csv('data/dataframe/passivo_circulante/emprestimo_financiamento.csv',index=False)
df_outras_obrigacoes.to_csv('data/dataframe/passivo_circulante/outras_obrigacoes.csv',index=False)
df_provisoes.to_csv('data/dataframe/passivo_circulante/provisoes.csv',index=False)
df_passivos.to_csv('data/dataframe/passivo_circulante/passivos.csv',index=False)


df_passivo_total = pd.DataFrame(columns=['company_id','codigo','reference_date','start_date','end_date','publish_date','retrieval_date'])
df_passivo_total.to_csv('data/dataframe/passivo_circulante/passivo_total.csv',index=False)

# %%
company_id = '33041260065290'

data = [] 

for emp in empresa:
    if emp['report_type']['acronym'] == 'BPP' and emp['reference_date'] not in data:
        data.append(emp['reference_date'])
        id = ativo_id()
        
        temp = pd.DataFrame(columns=['company_id','codigo','reference_date','start_date','end_date','publish_date','retrieval_date'])
        temp['company_id'] = [company_id]
        temp['codigo'] = [id]
        temp['reference_date'] = [emp['reference_date']]
        temp['start_date'] = [emp['start_date']]
        temp['end_date'] = [emp['end_date']]
        temp['publish_date'] = [emp['publish_date']]
        temp['retrieval_date'] = [emp['retrieval_date']]
        
        df_passivo_total = pd.read_csv('data/dataframe/passivo_circulante/passivo_total.csv')
        df_passivo_total = pd.concat([df_passivo_total, temp], ignore_index=True)
        df_passivo_total.to_csv('data/dataframe/passivo_circulante/passivo_total.csv',index=False)     
        
        circulante(id, company_id, emp['data'])
