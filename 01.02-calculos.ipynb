# %%
import pandas as pd

# %% [markdown]
# # Funções

# %%
def juntar_dataframe(df1,df2,nome2,nome1=None,):
    try :
        df1 = df1.rename(columns={'valor': nome1})
    except:
        pass
    df = pd.merge(df1, df2, on='ativo_id', how='left' )
    try:
        df.drop(columns=['start_date','end_date','retrieval_date','publish_date'], inplace=True)
    except:
        pass
    df = df.rename(columns={'valor': nome2})
    return df

# %% [markdown]
# # Ativo Circulante

# %%
circulante = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_total.csv")
aplicacao_financeira = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_aplicao_financeira.csv")
ativos_biologicos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_biologicos.csv")
caixa = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_caixa.csv")
contas_receber = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_contas_receber.csv")
despesas_antecipadas = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_despesas_atecipadas.csv")
estoques = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_estoque.csv")
outros_ativos_circulantes = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_outros_ativos_circulantes.csv")
tributos_recuperar = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_tributos.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 circulante = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_total.csv")
#       2 aplicacao_financeira = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_aplicao_financeira.csv")
#       3 ativos_biologicos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_biologicos.csv")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_circulante/ativo_total.csv'

# %%
ativo_circulante = juntar_dataframe(circulante,aplicacao_financeira,'aplicacao_financeira','ativo_circulante')
ativo_circulante = juntar_dataframe(ativo_circulante,ativos_biologicos,'ativo_biologico')
ativo_circulante = juntar_dataframe(ativo_circulante,caixa,'caixa')
ativo_circulante = juntar_dataframe(ativo_circulante,contas_receber,'contas_receber')
ativo_circulante = juntar_dataframe(ativo_circulante,despesas_antecipadas,'despesas_antecipadas')
ativo_circulante = juntar_dataframe(ativo_circulante,estoques,'estoques')
ativo_circulante = juntar_dataframe(ativo_circulante,outros_ativos_circulantes,'outros_ativos_circulantes')
ativo_circulante = juntar_dataframe(ativo_circulante,tributos_recuperar,'tributos_recuperar')

# %%
ativo_circulante.head()
# Out:
#    ativo_id      company_id        reference_date  ativo_circulante  codigo  \
# 0         1  33041260065290  2025-03-31T00:00:00Z       13565000000     NaN
# 1         2  33041260065290  2024-12-31T00:00:00Z       14140000000     NaN
# 2         3  33041260065290  2024-09-30T00:00:00Z       13429000000     NaN
# 3         4  33041260065290  2024-06-30T00:00:00Z       12733000000     NaN
# 4         5  33041260065290  2024-03-31T00:00:00Z       12506000000     NaN
#
#    aplicacao_financeira  ativo_biologico       caixa  contas_receber  \
# 0             266000000                0   935000000      4332000000
# 1             283000000                0  2131000000      4616000000
# 2             251000000                0  1868000000      3868000000
# 3                     0                0  1858000000      3789000000
# 4                     0                0  1868000000      3615000000
#
#    despesas_antecipadas    estoques  outros_ativos_circulantes  \
# 0             294000000  5034000000                  870000000
# 1             269000000  4695000000                  794000000
# 2             275000000  4777000000                  892000000
# 3             278000000  4360000000                  907000000
# 4             243000000  4355000000                  956000000
#
#    tributos_recuperar
# 0          1834000000
# 1          1352000000
# 2          1498000000
# 3          1541000000
# 4          1469000000

# %%
colunas_ativo_circulante = [
    'aplicacao_financeira',
    'ativo_biologico',
    'caixa',
    'contas_receber',
    'despesas_antecipadas',
    'estoques',
    'outros_ativos_circulantes',
    'tributos_recuperar'
]
ativo_circulante['total'] = ativo_circulante[colunas_ativo_circulante].sum(axis=1)

# %%
ativo_circulante.head()
# Out:
#    ativo_id      company_id        reference_date  ativo_circulante  codigo  \
# 0         1  33041260065290  2025-03-31T00:00:00Z       13565000000     NaN
# 1         2  33041260065290  2024-12-31T00:00:00Z       14140000000     NaN
# 2         3  33041260065290  2024-09-30T00:00:00Z       13429000000     NaN
# 3         4  33041260065290  2024-06-30T00:00:00Z       12733000000     NaN
# 4         5  33041260065290  2024-03-31T00:00:00Z       12506000000     NaN
#
#    aplicacao_financeira  ativo_biologico       caixa  contas_receber  \
# 0             266000000                0   935000000      4332000000
# 1             283000000                0  2131000000      4616000000
# 2             251000000                0  1868000000      3868000000
# 3                     0                0  1858000000      3789000000
# 4                     0                0  1868000000      3615000000
#
#    despesas_antecipadas    estoques  outros_ativos_circulantes  \
# 0             294000000  5034000000                  870000000
# 1             269000000  4695000000                  794000000
# 2             275000000  4777000000                  892000000
# 3             278000000  4360000000                  907000000
# 4             243000000  4355000000                  956000000
#
#    tributos_recuperar        total
# 0          1834000000  13565000000
# 1          1352000000  14140000000
# 2          1498000000  13429000000
# 3          1541000000  12733000000
# 4          1469000000  12506000000

# %% [markdown]
# # Ativo Não Circulante

# %%
circulante = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_nao_circulante/ativo_nao_circulante.csv")
imobilizado = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_nao_circulante/imobilizado.csv")
intangivel = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_nao_circulante/intangivel.csv")
investimentos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_nao_circulante/investimento.csv")
realizavel_longo_prazo = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/ativo_nao_circulante/realizavel_longo_prazo.csv")

# %%
ativo_nao_circulante = juntar_dataframe(circulante,imobilizado,'imobilizado','ativo_nao_circulante')
ativo_nao_circulante = juntar_dataframe(ativo_nao_circulante,intangivel,'intangivel')
ativo_nao_circulante = juntar_dataframe(ativo_nao_circulante,investimentos,'investimentos')
ativo_nao_circulante = juntar_dataframe(ativo_nao_circulante,realizavel_longo_prazo,'realizavel_longo_prazo')

# %%
colunas_ativo_nao_circulante = [
    'imobilizado',
    'intangivel',
    'investimentos',
    'realizavel_longo_prazo',
]
ativo_nao_circulante['total'] = ativo_nao_circulante[colunas_ativo_nao_circulante].sum(axis=1)

# %%
ativo_nao_circulante.head()
# Out:
#    ativo_id      company_id        reference_date  ativo_nao_circulante  \
# 0         1  33041260065290  2025-03-31T00:00:00Z           19251000000
# 1         2  33041260065290  2024-12-31T00:00:00Z           19749000000
# 2         3  33041260065290  2024-09-30T00:00:00Z           18598000000
# 3         4  33041260065290  2024-06-30T00:00:00Z           18443000000
# 4         5  33041260065290  2024-03-31T00:00:00Z           18827000000
#
#    codigo  imobilizado  intangivel  investimentos  realizavel_longo_prazo  \
# 0     NaN   3604000000  2670000000      267000000             12710000000
# 1     NaN   3712000000  2674000000      263000000             13100000000
# 2     NaN   3807000000  2690000000      244000000             11857000000
# 3     NaN   3875000000  2701000000      253000000             11614000000
# 4     NaN   3983000000  2724000000      231000000             11889000000
#
#          total
# 0  19251000000
# 1  19749000000
# 2  18598000000
# 3  18443000000
# 4  18827000000

# %% [markdown]
# # Passivo Circulante

# %%
passivo_cir = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/passivo_circulante.csv")
emprestimo = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/emprestimos.csv")
fornecedor = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/fornecedores.csv")
obr_fiscal = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/obr_fiscais.csv")
obr_social = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/obr_sociais_trabalhista.csv")
outras_obr = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/outras_obrigacoes.csv")
passivos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/passivos.csv")
provisoes = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_circulante/provisoes.csv")

# %%
passivo_circulante = juntar_dataframe(passivo_cir,emprestimo,'emprestimo','passivo_circulante')
passivo_circulante = juntar_dataframe(passivo_circulante,fornecedor,'fornecedor')
passivo_circulante = juntar_dataframe(passivo_circulante,obr_fiscal,'obr_fiscal')
passivo_circulante = juntar_dataframe(passivo_circulante,obr_social,'obr_social')
passivo_circulante = juntar_dataframe(passivo_circulante,outras_obr,'outras_obr')
passivo_circulante = juntar_dataframe(passivo_circulante,passivos,'passivos')
passivo_circulante = juntar_dataframe(passivo_circulante,provisoes,'provisoes')

# %%
passivo_circulante.head()
# Out:
#    ativo_id      company_id        reference_date  passivo_circulante  codigo  \
# 0         1  33041260065290  2025-03-31T00:00:00Z         18443000000     NaN
# 1         2  33041260065290  2024-12-31T00:00:00Z         19262000000     NaN
# 2         3  33041260065290  2024-09-30T00:00:00Z         17827000000     NaN
# 3         4  33041260065290  2024-06-30T00:00:00Z         16771000000     NaN
# 4         5  33041260065290  2024-03-31T00:00:00Z         17570000000     NaN
#
#    emprestimo  fornecedor  obr_fiscal  obr_social  outras_obr  passivos  \
# 0  5341000000  7810000000   660000000   589000000  4043000000         0
# 1  5224000000  8089000000   551000000   575000000  4823000000         0
# 2  5397000000  7446000000   412000000   538000000  4034000000         0
# 3  4882000000  7119000000   396000000   517000000  3857000000         0
# 4  5675000000  6982000000   389000000   460000000  4064000000         0
#
#    provisoes
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Passivo Não Circulante

# %%
passivo_nao_cir = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/passivo_nao_circulante.csv")
emprestimo = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/emprestimo_financiamento.csv")
lucro = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/lucro.csv")
outras_obr = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/outras_obrigacoes.csv")
passivos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/passivos.csv")
provisoes = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/provisoes.csv")
tributos = pd.read_csv("/home/rafael/00-Projetos/Renda_Investe/renda_investe-banco_de_dados/data/bd/passivo_nao_circulante/tributos.csv")

# %%
passivo_nao_circulante = juntar_dataframe(passivo_nao_cir,emprestimo,'emprestimo','passivo_nao_circulante')
passivo_nao_circulante = juntar_dataframe(passivo_nao_circulante,lucro,'lucro')
passivo_nao_circulante = juntar_dataframe(passivo_nao_circulante,outras_obr,'outras_obr')
passivo_nao_circulante = juntar_dataframe(passivo_nao_circulante,passivos,'passivos')
passivo_nao_circulante = juntar_dataframe(passivo_nao_circulante,provisoes,'provisoes')
passivo_nao_circulante = juntar_dataframe(passivo_nao_circulante,tributos,'tributos')

# %%
passivo_nao_circulante.head()
# Out:
#    ativo_id      company_id        reference_date  passivo_nao_circulante  \
# 0         1  33041260065290  2025-03-31T00:00:00Z             12284000000
# 1         2  33041260065290  2024-12-31T00:00:00Z             12150000000
# 2         3  33041260065290  2024-09-30T00:00:00Z             11321000000
# 3         4  33041260065290  2024-06-30T00:00:00Z             11163000000
# 4         5  33041260065290  2024-03-31T00:00:00Z             10561000000
#
#    codigo  emprestimo  lucro  outras_obr  passivos  provisoes  tributos
# 0     NaN  5341000000      0  4043000000         0          0  20000000
# 1     NaN  5224000000      0  4823000000         0          0  20000000
# 2     NaN  5397000000      0  4034000000         0          0  20000000
# 3     NaN  4882000000      0  3857000000         0          0  20000000
# 4     NaN  5675000000      0  4064000000         0          0  20000000

# %% [markdown]
# # Resultado

# %%
ativo_circulante.head(1)
# Out:
#    ativo_id      company_id        reference_date  ativo_circulante  codigo  \
# 0         1  33041260065290  2025-03-31T00:00:00Z       13565000000     NaN
#
#    aplicacao_financeira  ativo_biologico      caixa  contas_receber  \
# 0             266000000                0  935000000      4332000000
#
#    despesas_antecipadas    estoques  outros_ativos_circulantes  \
# 0             294000000  5034000000                  870000000
#
#    tributos_recuperar        total
# 0          1834000000  13565000000

# %%
ativo_nao_circulante.head(1)
# Out:
#    ativo_id      company_id        reference_date  ativo_nao_circulante  \
# 0         1  33041260065290  2025-03-31T00:00:00Z           19251000000
#
#    codigo  imobilizado  intangivel  investimentos  realizavel_longo_prazo  \
# 0     NaN   3604000000  2670000000      267000000             12710000000
#
#          total
# 0  19251000000

# %%
resultado = pd.DataFrame()
resultado['data'] = ativo_circulante['reference_date']
resultado['ativo'] = ativo_circulante['total'] + ativo_nao_circulante['total']
resultado['disponibilidade'] = ativo_circulante['caixa'] + ativo_circulante['aplicacao_financeira']
resultado['ativo_circulante'] = ativo_circulante['total']
resultado['divida_bruta'] = passivo_nao_circulante['emprestimo'] + passivo_circulante['emprestimo']
resultado['divida_liquida'] = resultado['divida_bruta'] - resultado['disponibilidade']
# resultado['patrimonio_liquido'] =

# %%
resultado.head()
# Out:
#                    data        ativo  disponibilidade  ativo_circulante  \
# 0  2025-03-31T00:00:00Z  32816000000       1201000000       13565000000
# 1  2024-12-31T00:00:00Z  33889000000       2414000000       14140000000
# 2  2024-09-30T00:00:00Z  32027000000       2119000000       13429000000
# 3  2024-06-30T00:00:00Z  31176000000       1858000000       12733000000
# 4  2024-03-31T00:00:00Z  31333000000       1868000000       12506000000
#
#    divida_bruta  divida_liquida
# 0   10682000000      9481000000
# 1   10448000000      8034000000
# 2   10794000000      8675000000
# 3    9764000000      7906000000
# 4   11350000000      9482000000
